# %% [markdown]
# # Fase 2: Análisis Univariado
#
# En esta etapa se analiza cada variable de manera individual con el propósito de comprender su distribución, identificar valores atípicos y conocer el comportamiento general de los indicadores educativos.
#
# Este análisis permitirá establecer una base sólida antes de explorar relaciones entre variables en las siguientes etapas del proyecto.

# %%
# configuracion de grafico 

plt.rcParams["figure.figsize"] = (10,5)

# %% [markdown]
# ## Estadísticas descriptivas
#
# Se presentan las principales medidas estadísticas de las variables numéricas para obtener una visión general de los datos.

# %%
df.describe().round(2)

# %% [markdown]
# ## Distribución de la deserción
#
# Se analiza cómo se distribuyen los porcentajes de deserción entre los departamentos y años registrados.

# %%
plt.hist(df["desercion"], bins=20)

plt.title("Distribución de la Deserción")
plt.xlabel("Deserción (%)")
plt.ylabel("Frecuencia")

plt.show()

# %% [markdown]
# ## Top departamentos con mayor deserción

# %%
top_desercion = (
    df.groupby("departamento")["desercion"]
      .mean()
      .sort_values(ascending=False)
      .head(10)
)

top_desercion.plot(kind="bar")

plt.title("Top 10 departamentos con mayor deserción")

plt.ylabel("Deserción promedio (%)")

plt.show()

# %% [markdown]
# ## Distribución del índice de riesgo

# %%
plt.hist(df["riesgo_academico"], bins=20)

plt.title("Distribución del Índice de Riesgo Académico")

plt.xlabel("Índice")

plt.show()

# %% [markdown]
# ## Distribución del balance académico

# %%
plt.hist(df["balance_academico"], bins=20)

plt.title("Distribución del Balance Académico")

plt.xlabel("Balance")

plt.show()

# %% [markdown]
# ## Evolución anual de la deserción

# %%
promedio = df.groupby("ano")["desercion"].mean()

promedio.plot(marker="o")

plt.title("Deserción promedio por año")

plt.ylabel("%")

plt.show()

# %% [markdown]
# ## Boxplot para valores atipicos

# %%
plt.boxplot(df["desercion"])

plt.title("Boxplot de la Deserción")

plt.show()

# %% [markdown]
# # Fase 3. Análisis bivariado

# %% [markdown]
# ¿Existe relación entre repitencia y deserción?

# %%
df[['repitencia', 'desercion']].corr()

# %% [markdown]
# ### ¿Qué significa este número?
#
# * Dirección de la relación: El valor es positivo ($>0$). Esto significa que ambas variables se mueven en la misma dirección; teóricamente, a medida que aumenta la tasa de repitencia en un departamento, también tiende a aumentar la tasa de deserción.
#
# * Fuerza de la relación: El coeficiente de Pearson va de $-1$ a $1$. Un valor de $0.104$ está extremadamente cerca de $0$, lo que significa que existe una correlación lineal positiva muy débil (casi inexistente) entre perder el año (repitencia) y abandonar el colegio (deserción) a nivel departamental.
#
# | Valor | Interpretación             |
# | ----- | -------------------------- |
# | 1     | Relación positiva perfecta |
# | 0.7   | Relación positiva fuerte   |
# | 0.5   | Relación moderada          |
# | 0.3   | Relación débil             |
# | **0** | Sin relación lineal        |
# | -0.3  | Relación negativa débil    |
# | -0.7  | Relación negativa fuerte   |
# | -1    | Relación negativa perfecta |

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='repitencia', y='desercion', alpha=0.6, color='blue')
plt.title('Relación entre Repitencia y Deserción por Departamento')
plt.xlabel('Tasa de Repitencia (%)')
plt.ylabel('Tasa de Deserción (%)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# **Hallazgo Clave**: Podemos observar que existen departamentos con altas tasas de repitencia (superiores al $12.5\%$) que mantienen niveles de deserción controlados o promedio (entre $2\%$ y $6\%$). De igual manera, se aprecian registros con baja repitencia pero niveles de deserción críticos (cercanos al $10\%$).
#
# **Conclusión**: La pérdida de año escolar (repitencia) no es un predictor directo ni la causa principal de la deserción estudiantil en las regiones de Colombia. El fenómeno del abandono de las aulas responde a dinámicas distintas a las del rendimiento académico tradicional.

# %%
df[['reprobacion', 'desercion']].corr()

# %% [markdown]
# ## ¿Qué significa este resultado?
#
# * Dirección: Es una correlación positiva. A mayor índice de reprobación en un departamento, mayor tiende a ser la tasa de deserción escolar.
#
# * Fuerza: En estadística, un valor entre $0.30$ y $0.50$ se considera una correlación positiva moderada o aceptable en ciencias sociales y educación. Ya no es una relación casi inexistente como la anterior; aquí los datos empiezan a mostrar una tendencia real.

# %% [markdown]
# ### ¿Por qué pasa esto? (El análisis detrás de los datos)
#
# Este resultado tiene mucho sentido pedagógico. La reprobación mide el porcentaje de materias individuales que los estudiantes van perdiendo a lo largo del año académico (matemáticas, lenguaje, ciencias), mientras que la repitencia es la pérdida total del año.
#
# El dato de $0.313$ sugiere que la frustración acumulada de ir perdiendo asignaturas mes a mes impacta de manera más inmediata en la decisión de un estudiante de abandonar el colegio, posiblemente debido a la desmotivación o la falta de refuerzo académico, antes de llegar incluso a la instancia de repetir el año escolar completo.

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='reprobacion', y='desercion', alpha=0.6, color='blue')
plt.title('Relación entre Reprobacion y Deserción por Departamento')
plt.xlabel('Tasa de Reprobacion (%)')
plt.ylabel('Tasa de Deserción (%)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### Análisis del Gráfico de Dispersión: Reprobación vs. Deserción
#
# * **Tendencia Visual**: A diferencia del gráfico de repitencia, aquí se empieza a notar una inclinación diagonal positiva. Los departamentos que registran tasas de reprobación más altas (especialmente por encima del $12.5\%$) tienden a ubicarse en la parte superior del gráfico, superando el $6\%$ de deserción escolar.
#
# * **Comparación de Hipótesis**: Visual y matemáticamente ($r = 0.313$), la reprobación tiene un peso significativamente mayor sobre la deserción que la repitencia ($r = 0.104$). Esto sugiere que el rezago o la dificultad con materias específicas genera una desconexión o desmotivación previa que empuja al estudiante a abandonar el sistema antes de que se consume la pérdida del año lectivo.
#
# * **Conclusión Estratégica**: Las políticas públicas orientadas a mitigar la deserción escolar en Colombia deberían enfocarse en alertas tempranas cuando el estudiante empieza a reprobar asignaturas durante el periodo escolar, en lugar de actuar únicamente cuando el estudiante ya ha reprobado el año completo.

# %%
plt.figure(figsize=(8, 5))
# sns.regplot dibuja los puntos Y la línea de tendencia de la correlación
sns.regplot(data=df, x='reprobacion', y='desercion', scatter_kws={'alpha':0.6, 'color':'blue'}, line_kws={'color':'red'})
plt.title('Tendencia Lineal: Reprobación vs Deserción por Departamento')
plt.xlabel('Tasa de Reprobación (%)')
plt.ylabel('Tasa de Deserción (%)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
df[['aprobacion', 'desercion']].corr()

# %% [markdown]
# ### ¿Qué significa este número?
#
# * **Dirección (Negativa / Inversa)**: Al tener un signo menos ($-$), significa que las variables se mueven en direcciones opuestas. Es decir, a medida que la tasa de aprobación de un departamento sube, la tasa de deserción baja de forma muy marcada (y viceversa).
#
# * **Fuerza (Fuerte)**: En estadística y analítica de datos sociales, un valor absoluto entre $0.50$ y $0.70$ (sin importar el signo) se clasifica como una correlación fuerte. Esto demuestra que la aprobación escolar está masivamente ligada al fenómeno del abandono de las aulas.

# %%
plt.figure(figsize=(8, 5))
# sns.regplot dibuja los puntos Y la línea de tendencia de la correlación
sns.regplot(data=df, x='aprobacion', y='desercion', scatter_kws={'alpha':0.6, 'color':'blue'}, line_kws={'color':'red'})
plt.title('Tendencia Lineal: Aprobacion vs Deserción por Departamento')
plt.xlabel('Tasa de Aprobacion (%)')
plt.ylabel('Tasa de Deserción (%)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# ### Análisis del Gráfico de Regresión: Aprobación vs. Deserción
#
# * **Comportamiento de la Tendencia**: La línea de regresión lineal presenta una pendiente negativa pronunciada. Esto valida de forma visual el coeficiente de Pearson de $-0.636$. A medida que nos desplazamos hacia la derecha en el eje X (mayor porcentaje de aprobación), los puntos caen drásticamente en el eje Y (menor deserción).
#
# * **Distribución de los Datos**: Podemos observar que cuando los departamentos alcanzan niveles de aprobación superiores al $95\%$, la deserción se contiene casi siempre por debajo del $4\%$. Por el contrario, en los escenarios donde la aprobación cae por debajo del $80\%$, las tasas de deserción se disparan de forma crítica, superando el $8\%$ e incluso el $10\%$.
#
# * **Conclusión de la Fase Bivariada**: El éxito académico global (aprobación) es la variable con mayor poder explicativo sobre la deserción de todas las analizadas hasta el momento. Esto demuestra que los entornos educativos capaces de retener y promover exitosamente a sus estudiantes actúan como el principal factor protector contra el abandono escolar en las regiones de Colombia.
