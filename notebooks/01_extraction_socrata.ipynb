# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Enable aggressive, automatic tab completion for the current notebook session
# %config IPCompleter.greedy=True

# %% [markdown]
# ## Fase 1: Exploración del dataset (EDA)
#
# En esta etapa exploraremos los datos que tenemos como cantidad de filas y colunas, tipos de datos, valores nulos, registros duplicados, estadistica descriptiva, etc

# %%
dataset_id = "ji8i-4anb"

url = f"https://www.datos.gov.co/resource/{dataset_id}.csv?$limit=500000"

print("Descargando datos desde datos.gov.co...")

df_original = pd.read_csv(url)

df = df_original

df.to_csv("../data/raw/education_data_raw.csv", index=False)

df.head()
# Out:
# Descargando datos desde datos.gov.co...
